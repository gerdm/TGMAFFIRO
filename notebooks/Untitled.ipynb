# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = np.vectorize(lambda x: x ** 2 )

# %%
x = np.linspace(-2, 2, 100)
plt.plot(x, f(x))

# %%
(f(x).max() - f(x).min()) /
# Out:
# 3.999591878379757
