# %% [markdown]
# #  Brownian Motion

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import normal, seed
# %matplotlib inline

# %%
seed(1643)
W1 = normal(size=400).cumsum()
W2 = normal(size=400).cumsum()

plt.figure(figsize=(15,10), dpi=200)
plt.plot(W1 * W2, W2);
